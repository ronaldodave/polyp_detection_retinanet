# %%
from train_retinanet import plot_history
import pandas as pd

# %% [markdown]
# ## ResNet-50 without Data Augmentation

# %%
df_resnet50_1 = pd.read_csv("./result/retinanet_resnet50_log.csv")

# %%
df_resnet50_1.head()
# Out:
#    epoch  classification_loss      loss       mAP  regression_loss  \
# 0      0             0.836386  3.426505  0.211220         2.590120
# 1      1             0.946200  3.150482  0.000000         2.204280
# 2      2             0.936171  2.837958  0.251070         1.901785
# 3      3             0.597161  2.275174  0.592894         1.678013
# 4      4             0.425003  1.959777  0.696626         1.534775
#
#    val_classification_loss  val_loss  val_regression_loss
# 0                 0.462283  3.024849             2.562567
# 1                 1.074596  3.192944             2.118348
# 2                 0.762077  2.605914             1.843838
# 3                 0.466330  2.068305             1.601976
# 4                 0.339894  1.822554             1.482660

# %%
epochs = 50
fig = './result/retinanet_resnet50.png'
title = 'Polyp Detection Using RetinaNet (Backbone = ResNet50)'
plot_history(df_resnet50_1, fig, title, epochs)

# %% [markdown]
# ## ResNet-50 with Data Augmentation

# %%
df_resnet50_2 = pd.read_csv("./result/retinanet_resnet50_aug_log.csv")

# %%
fig = './result/retinanet_resnet50_aug.png'
title = 'Polyp Detection Using RetinaNet (Backbone = ResNet50) with Data Augmentation'
plot_history(df_resnet50_2, fig, title, epochs)

# %% [markdown]
# ## ResNet-101 without Data Augmentation

# %%
df_resnet101_1 = pd.read_csv("./result/retinanet_resnet101_log.csv")

# %%
fig = './result/retinanet_resnet101.png'
title = 'Polyp Detection Using RetinaNet (Backbone = ResNet101)'
plot_history(df_resnet101_1, fig, title, epochs)

# %% [markdown]
# ## ResNet-101 with Data Augmentation

# %%
df_resnet101_2 = pd.read_csv("./result/retinanet_resnet101_aug_log.csv")

# %%
fig = './result/retinanet_resnet101_aug.png'
title = 'Polyp Detection Using RetinaNet (Backbone = ResNet101) with Data Augmentation'
plot_history(df_resnet101_2, fig, title, epochs)

# %% [markdown]
# ## ResNet-152 without Data Augmentation

# %%
df_resnet152_1 = pd.read_csv("./result/retinanet_resnet152_log.csv")

# %%
fig = './result/retinanet_resnet152.png'
title = 'Polyp Detection Using RetinaNet (Backbone = ResNet152)'
plot_history(df_resnet152_1, fig, title, epochs)

# %% [markdown]
# ## ResNet-152 with Data Augmentation

# %%
df_resnet152_2 = pd.read_csv("./result/retinanet_resnet152_aug_log.csv")

# %%
fig = './result/retinanet_resnet152_aug.png'
title = 'Polyp Detection Using RetinaNet (Backbone = ResNet152) with Data Augmentation'
plot_history(df_resnet152_2, fig, title, epochs)
